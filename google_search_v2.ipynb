# %%
pip install pytrends pandas numpy tqdm
# Out:
# Requirement already satisfied: pytrends in c:\users\inesa\anaconda3\lib\site-packages (4.9.2)
# Requirement already satisfied: pandas in c:\users\inesa\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\inesa\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: tqdm in c:\users\inesa\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: requests>=2.0 in c:\users\inesa\anaconda3\lib\site-packages (from pytrends) (2.32.5)
# Requirement already satisfied: lxml in c:\users\inesa\anaconda3\lib\site-packages (from pytrends) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\inesa\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\inesa\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\inesa\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: colorama in c:\users\inesa\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\inesa\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\inesa\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\inesa\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\inesa\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\inesa\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "urllib3<2.0"
# Out:
# Requirement already satisfied: urllib3<2.0 in c:\users\inesa\anaconda3\lib\site-packages (1.26.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import time
import random
from datetime import timedelta
from tqdm import tqdm
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(
    hl="en-US",
    tz=360,
    retries=2,              # low retries, avoid hammering
    backoff_factor=0.1
)

# %%
suggestions = pytrends.suggestions("Israeli-Palestinian conflict")

topic_mid = [s["mid"] for s in suggestions if s["type"] == "Topic"][0]
topic_mid
# Out:
# '/m/0cj5y'

# %%
def polite_sleep(low=8, high=15):
    time.sleep(random.uniform(low, high))

def get_weekly_anchor(start, end):
    polite_sleep(10, 20)

    pytrends.build_payload(
        kw_list=[topic_mid],
        geo="US",
        timeframe=f"{start} {end}"
    )

    df = pytrends.interest_over_time()
    df = df.drop(columns=["isPartial"])
    df = df.rename(columns={topic_mid: "weekly"})
    return df

def get_daily_window(start, end):
    polite_sleep(8, 15)

    pytrends.build_payload(
        kw_list=[topic_mid],
        geo="US",
        timeframe=f"{start} {end}"
    )

    df = pytrends.interest_over_time()
    df = df.drop(columns=["isPartial"])
    df = df.rename(columns={topic_mid: "daily"})
    return df

# %%
weekly_parts = []

for y in range(2004, 2020, 3):
    try:
        print(f"Weekly anchor: {y}-{y+2}")
        part = get_weekly_anchor(f"{y}-01-01", f"{y+2}-12-31")
        weekly_parts.append(part)
    except Exception as e:
        print(f"Skipped weekly block {y}: {e}")
        continue

weekly = pd.concat(weekly_parts).sort_index()
# Out:
# Weekly anchor: 2004-2006
# Weekly anchor: 2007-2009
# Weekly anchor: 2010-2012
# Weekly anchor: 2013-2015
# Weekly anchor: 2016-2018
# Weekly anchor: 2019-2021
# Weekly anchor: 2022-2024
# Weekly anchor: 2025-2027
# c:\Users\inesa\anaconda3\Lib\site-packages\pytrends\request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %%
start_date = pd.to_datetime("2004-01-01")
end_date   = pd.to_datetime("2026-01-01")

windows = []
current = start_date

while current < end_date:
    window_end = min(current + timedelta(days=89), end_date)
    windows.append((current, window_end))
    current = window_end + timedelta(days=1)

# %%
daily_scaled = []

for start, end in tqdm(windows):

    try:
        daily = get_daily_window(
            start.strftime("%Y-%m-%d"),
            end.strftime("%Y-%m-%d")
        )
    except Exception as e:
        print(f"Skipped {start}–{end}: {e}")
        continue

    if daily.empty:
        continue

    # Convert daily → weekly
    daily_weekly = daily.resample("W-SUN").mean()

    # Merge with anchor
    merged = daily_weekly.join(weekly, how="inner")

    if merged.empty:
        continue

    # Scaling factor
    scale = (merged["weekly"] / merged["daily"]).mean()

    daily["scaled"] = daily["daily"] * scale
    daily_scaled.append(daily[["scaled"]])
# Out:
# 100%|██████████| 90/90 [20:00<00:00, 13.34s/it]

# %%
daily_final = (
    pd.concat(daily_scaled)
    .sort_index()
    .loc[~pd.concat(daily_scaled).index.duplicated()]
)

daily_final = daily_final.rename(columns={"scaled": "google_search_index"})

# %%
daily_final["google_search_index"] = (
    100 * daily_final["google_search_index"]
    / daily_final["google_search_index"].max()
)

# %%
daily_final.to_csv("google_trends_israel_palestine_daily_US.csv")

# %%
test_start = "2004-09-01"
test_end   = "2004-11-30"

pytrends.build_payload(
    kw_list=[topic_mid],
    geo="US",
    timeframe=f"{test_start} {test_end}"
)

test_daily = pytrends.interest_over_time()
test_daily
# Out:
#             /m/0cj5y  isPartial
# date
# 2004-09-01         0      False
# 2004-09-02         0      False
# 2004-09-03         0      False
# 2004-09-04         0      False
# 2004-09-05         0      False
# ...              ...        ...
# 2004-11-26         0      False
# 2004-11-27         0      False
# 2004-11-28         0      False
# 2004-11-29        31      False
# 2004-11-30        34      False
#
# [91 rows x 2 columns]

# %%
pytrends.build_payload(
    kw_list=[topic_mid],
    geo="US",
    timeframe="2004-01-01 2006-12-31"
)

test_weekly = pytrends.interest_over_time()
test_weekly.describe()
# Out:
#          /m/0cj5y
# count  158.000000
# mean    28.348101
# std     14.357549
# min      0.000000
# 25%     17.250000
# 50%     27.000000
# 75%     36.000000
# max    100.000000
